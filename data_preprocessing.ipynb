# %%
import pandas as pd

# %%
df = pd.read_csv('./oasis_cross-sectional.csv')

# %%
def cull_non_alz_df(df):
    people_no_alz = df[df['CDR'].notna()]
    people_no_alz = df[df['Age'] >= 73]
    people_no_alz = (people_no_alz[people_no_alz["MMSE"] <= 27])
    people_no_alz = people_no_alz[people_no_alz["Educ"] <= 3]
    return people_no_alz

# %%
alz = df[df['CDR'] == 1]
no_alz = cull_non_alz_df(df[df['CDR'] < 1])

print('alz len: ', len(alz), '; no-alz len: ', len(no_alz))
# Out:
# alz len:  28 ; no-alz len:  28

# %%
def create_candidate_df(alz_df, no_alz_df):
    alz_df["alz"] = 1;
    no_alz_df["alz"] = 0;
    new_df = alz_df.append(no_alz_df)
    return new_df

# %%
new_df = create_candidate_df(alz, no_alz)
new_df
# Out:
# <ipython-input-7-df9a06c2eac0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alz_df["alz"] = 1;
#                 ID M/F Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF  \
# 25   OAS1_0028_MR1   F    R   86   2.0  4.0  27.0  1.0  1449  0.738  1.211
# 28   OAS1_0031_MR1   M    R   88   1.0  4.0  26.0  1.0  1419  0.674  1.236
# 32   OAS1_0035_MR1   F    R   84   3.0  2.0  28.0  1.0  1402  0.695  1.252
# 47   OAS1_0052_MR1   F    R   78   1.0  5.0  23.0  1.0  1462  0.697  1.200
# 48   OAS1_0053_MR1   F    R   83   1.0  4.0  21.0  1.0  1384  0.699  1.268
# 51   OAS1_0056_MR1   F    R   72   3.0  3.0  15.0  1.0  1324  0.668  1.325
# 62   OAS1_0067_MR1   F    R   71   4.0  1.0  27.0  1.0  1549  0.730  1.133
# 68   OAS1_0073_MR1   F    R   69   2.0  4.0  21.0  1.0  1495  0.655  1.174
# 113  OAS1_0122_MR1   F    R   83   5.0  2.0  22.0  1.0  1377  0.715  1.274
# 124  OAS1_0134_MR1   M    R   80   2.0  4.0  20.0  1.0  1494  0.665  1.175
# 127  OAS1_0137_MR1   F    R   87   2.0  3.0  22.0  1.0  1499  0.672  1.171
# 169  OAS1_0184_MR1   F    R   65   2.0  NaN  16.0  1.0  1521  0.669  1.154
# 170  OAS1_0185_MR1   F    R   78   2.0  4.0  17.0  1.0  1314  0.739  1.336
# 203  OAS1_0223_MR1   M    R   84   2.0  NaN  20.0  1.0  1641  0.703  1.070
# 241  OAS1_0268_MR1   M    R   78   2.0  3.0  23.0  1.0  1491  0.715  1.177
# 242  OAS1_0269_MR1   F    R   72   1.0  4.0  21.0  1.0  1489  0.683  1.179
# 250  OAS1_0278_MR1   F    R   96   5.0  1.0  26.0  1.0  1465  0.684  1.198
# 263  OAS1_0291_MR1   F    R   73   2.0  2.0  19.0  1.0  1274  0.745  1.377
# 286  OAS1_0316_MR1   F    R   72   4.0  2.0  22.0  1.0  1493  0.690  1.176
# 337  OAS1_0373_MR1   F    R   80   3.0  2.0  20.0  1.0  1732  0.692  1.013
# 346  OAS1_0382_MR1   F    R   67   4.0  NaN  15.0  1.0  1288  0.763  1.362
# 352  OAS1_0388_MR1   F    R   77   2.0  4.0  22.0  1.0  1350  0.736  1.300
# 361  OAS1_0399_MR1   M    R   78   2.0  NaN  29.0  1.0  1569  0.706  1.119
# 367  OAS1_0405_MR1   M    R   77   5.0  1.0  23.0  1.0  1713  0.761  1.024
# 384  OAS1_0424_MR1   M    R   75   4.0  1.0  20.0  1.0  1613  0.715  1.088
# 385  OAS1_0425_MR1   F    R   78   1.0  4.0  23.0  1.0  1461  0.715  1.201
# 389  OAS1_0430_MR1   M    R   71   4.0  1.0  17.0  1.0  1562  0.687  1.123
# 410  OAS1_0452_MR1   M    R   75   1.0  4.0  22.0  1.0  1656  0.762  1.060
# 14   OAS1_0016_MR1   M    R   82   2.0  4.0  27.0  0.5  1477  0.739  1.188
# 19   OAS1_0021_MR1   F    R   80   3.0  3.0  23.0  0.5  1794  0.765  0.978
# 21   OAS1_0023_MR1   M    R   82   2.0  3.0  27.0  0.5  1420  0.710  1.236
# 60   OAS1_0065_MR1   M    R   90   2.0  3.0  25.0  0.0  1301  0.645  1.349
# 79   OAS1_0084_MR1   F    R   81   2.0  NaN  27.0  0.5  1453  0.727  1.208
# 114  OAS1_0123_MR1   F    R   83   3.0  4.0  24.0  0.5  1282  0.797  1.369
# 115  OAS1_0124_MR1   M    R   73   2.0  NaN  23.0  0.5  1661  0.709  1.056
# 149  OAS1_0161_MR1   F    R   84   2.0  2.0  27.0  0.5  1390  0.727  1.263
# 154  OAS1_0166_MR1   F    R   80   2.0  NaN  27.0  0.5  1475  0.771  1.190
# 164  OAS1_0179_MR1   F    R   87   2.0  4.0  21.0  0.5  1250  0.653  1.405
# 205  OAS1_0226_MR1   M    R   90   1.0  4.0  23.0  0.5  1668  0.644  1.052
# 212  OAS1_0233_MR1   F    R   77   1.0  4.0  20.0  0.5  1376  0.701  1.275
# 219  OAS1_0240_MR1   F    R   74   2.0  NaN  26.0  0.5  1171  0.736  1.499
# 224  OAS1_0247_MR1   M    R   90   2.0  3.0  21.0  0.5  1307  0.689  1.342
# 244  OAS1_0271_MR1   F    R   89   2.0  4.0  27.0  0.0  1329  0.740  1.320
# 245  OAS1_0272_MR1   F    R   75   3.0  2.0  26.0  0.5  1355  0.745  1.296
# 246  OAS1_0273_MR1   F    R   89   1.0  4.0  18.0  0.5  1480  0.676  1.186
# 258  OAS1_0286_MR1   F    R   83   3.0  2.0  20.0  0.5  1476  0.751  1.189
# 259  OAS1_0287_MR1   F    R   78   3.0  3.0  21.0  0.5  1194  0.694  1.470
# 262  OAS1_0290_MR1   M    R   83   3.0  2.0  26.0  0.5  1992  0.706  0.881
# 282  OAS1_0312_MR1   F    R   73   3.0  NaN  26.0  0.5  1311  0.756  1.339
# 298  OAS1_0330_MR1   F    R   80   1.0  5.0  27.0  0.0  1381  0.752  1.270
# 302  OAS1_0335_MR1   F    R   80   1.0  4.0  27.0  0.5  1654  0.678  1.061
# 306  OAS1_0339_MR1   F    R   79   2.0  NaN  24.0  0.5  1211  0.694  1.449
# 320  OAS1_0354_MR1   M    R   74   1.0  3.0  26.0  0.0  1367  0.776  1.284
# 344  OAS1_0380_MR1   F    R   83   1.0  5.0  18.0  0.5  1313  0.705  1.337
# 398  OAS1_0440_MR1   M    R   86   1.0  4.0  27.0  0.5  1320  0.723  1.329
# 412  OAS1_0454_MR1   F    R   73   3.0  2.0  23.0  0.5  1536  0.730  1.142
#
#      Delay  alz
# 25     NaN    1
# 28     NaN    1
# 32     NaN    1
# 47     NaN    1
# 48     NaN    1
# 51     NaN    1
# 62     NaN    1
# 68     NaN    1
# 113    NaN    1
# 124    NaN    1
# 127    NaN    1
# 169    NaN    1
# 170    NaN    1
# 203    NaN    1
# 241    NaN    1
# 242    NaN    1
# 250    NaN    1
# 263    NaN    1
# 286    NaN    1
# 337    NaN    1
# 346    NaN    1
# 352    NaN    1
# 361    NaN    1
# 367    NaN    1
# 384    NaN    1
# 385    NaN    1
# 389    NaN    1
# 410    NaN    1
# 14     NaN    0
# 19     NaN    0
# 21     NaN    0
# 60     NaN    0
# 79     NaN    0
# 114    NaN    0
# 115    NaN    0
# 149    NaN    0
# 154    NaN    0
# 164    NaN    0
# 205    NaN    0
# 212    NaN    0
# 219    NaN    0
# 224    NaN    0
# 244    NaN    0
# 245    NaN    0
# 246    NaN    0
# 258    NaN    0
# 259    NaN    0
# 262    NaN    0
# 282    NaN    0
# 298    NaN    0
# 302    NaN    0
# 306    NaN    0
# 320    NaN    0
# 344    NaN    0
# 398    NaN    0
# 412    NaN    0

# %%
# save csv

new_df.to_csv('patient_ids.csv')
